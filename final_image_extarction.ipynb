# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

def adaptive_thresh(path):
    img = cv.imread(path,0)
#     print("original image")
#     plt.imshow(img)
    width, height = 150, 150        #dimensions of the region of interest is to defined wrt image selected.
    x, y = 250, 350
    # Crop image to specified area using slicing
    img = img[y:y+height, x:x+width]
#     print("cropped image")
#     plt.imshow(img)
    img = cv.medianBlur(img,3)
#     print("median blurred image")
#     plt.imshow(img)
    ret,th1 = cv.threshold(img,127,255,cv.THRESH_BINARY)
    th2 = cv.adaptiveThreshold(img,255,cv.ADAPTIVE_THRESH_MEAN_C,\
                cv.THRESH_BINARY,11,2)
    th3 = cv.adaptiveThreshold(img,255,cv.ADAPTIVE_THRESH_GAUSSIAN_C,\
                cv.THRESH_BINARY,11,2)
    titles = ['Original Image', 'Global Thresholding (v = 127)',
                'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
    images = [img, th1, th2, th3]
    for i in range(4):
        plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
        plt.title(titles[i])
        plt.xticks([]),plt.yticks([])
    plt.show()
    print("adaptive mean threshold")
    plt.imshow(images[2],'gray')
    return images[2]

path =r'C:\Autosys_internship\Assignment for Internship_at_Autoyos\Internship at Autoyos\4.png'
i=adaptive_thresh(path)
# Out:
# cropped image
# median blurred image
# adaptive mean threshold

# %% [markdown]
# Inverting the thresholded image

# %%
img2=i
# grayImage = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
  
(thresh, blackAndWhiteImage) = cv.threshold(img2, 0, 0, cv.THRESH_BINARY)
inverted_image = cv.bitwise_not(img2)
kernel = np.ones((2, 2), np.uint8)
img_dilation = cv.dilate(inverted_image, kernel, iterations=1)
plt.imshow(img_dilation,'gray')

# %% [markdown]
# ORIGINAL IMAGE

# %%
print('original image')
plt.imshow(cv.imread(path,0),'gray')
# Out:
# original image

# %% [markdown]
# CROPPED ORIGINAL IMAGE

# %%
img = cv.imread(path,0)
#     print("original image")
#     plt.imshow(img)
width, height = 150, 150        #dimensions of the region of interest is to defined wrt image selected.
x, y = 250, 350
# Crop image to specified area using slicing
img = img[y:y+height, x:x+width]
print("cropped image")
plt.imshow(img,'gray')
# Out:
# cropped image
